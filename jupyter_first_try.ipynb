# %%
print("你好!这是我的第一个jupyter Notebook代码")
# Out:
# 你好!这是我的第一个jupyter Notebook代码

# %%
import numpy
result = 5+3
print(f"5+3 = {result}")
# Out:
# 5+3 = 8

# %%
a=10
b=8
sum = a + b
print(f"a+b={sum}")
# Out:
# a+b=18

# %%
difference = a-b
print(f"a-b={difference}")
# Out:
# a-b=2
